# %%
import pandas as pd
import os

# %%
sumZoneTripAndMode =  "E:\GitHub\WF-TDM-v9x\_working-bill\results"
scnJson = "_site/scenarios.json"
outputJsonName = "zones-se-vizmap.json"

# %%
# attributes for road seg summaries
dfAttributes = pd.DataFrame([
    ["TOTHH"     , "Total Households"               ],
    ["HHPOP"     , "Household Population"           ],
    ["HHSIZE"    , "Household Size"                 ],
    ["TOTEMP"    , "Typical Employment"             ],
    ["RETEMP"    , "Retail Employment"              ],
    ["INDEMP"    , "Industrial Employment"          ],
    ["OTHEMP"    , "Other Employment"               ],
    ["ALLEMP"    , "All Employment"                 ],
    ["RETL"      , "Retail Employment (RETL)"       ],
    ["FOOD"      , "Food Employment"                ],
    ["MANU"      , "Manufacturing Employment"       ],
    ["WSLE"      , "Wholesale Employment"           ],
    ["OFFI"      , "Office Employment"              ],
    ["GVED"      , "Government/Education Employment"],
    ["HLTH"      , "Health Employment"              ],
    ["OTHR"      , "Other Employment"               ],
    ["AGRI"      , "Agricultural Employment"        ],
    ["MING"      , "Mining Employment"              ],
    ["CONS"      , "Construction Employment"        ],
    ["HBJ"       , "Home-Based Job Employment"      ],
    ["AVGINCOME" , "Average Income"                 ],
    ["ENROL_ELEM", "Elementary School Enrollment"   ],
    ["ENROL_MIDL", "Middle School Enrollment"       ],
    ["ENROL_HIGH", "High School Enrollment"         ]
], columns=('aCode','aName'))
display(dfAttributes)

dfFilters = pd.DataFrame([
#    ["fPurp","Trip Purpose"         , "select", True ],
#    ["fMode","Mode"                 , "select", True ],
#    ["fTod" ,"Time of Day"          , "select", True ],
#    ["fPA"  ,"Production/Attraction", "select", False]
], columns=('fCode','fName','fWidget','fOwnCol'))
display(dfFilters)

lstFiltersOwnCol = dfFilters[dfFilters['fOwnCol'] == True]['fCode'].tolist()
display(lstFiltersOwnCol)

# MAKE SURE ONLY COLUMNS WITH LOWER-CASE "f" ARE FILTER COLUMNS AND LOWER-CASE "a" ARE ATTRIBUTE COLUMNS

dfColKeys = pd.DataFrame([
    ["aTotHh"    ,"TOTHH"     ],
    ["aHhPop"    ,"HHPOP"     ],
    ["aHhSize"   ,"HHSIZE"    ],
    ["aTotEmp"   ,"TOTEMP"    ],
    ["aRetEmp"   ,"RETEMP"    ],
    ["aIndEmp"   ,"INDEMP"    ],
    ["aOthEmp"   ,"OTHEMP"    ],
    ["aAllEmp"   ,"ALLEMP"    ],
    ["aRetl"     ,"RETL"      ],
    ["aFood"     ,"FOOD"      ],
    ["aManu"     ,"MANU"      ],
    ["aWsle"     ,"WSLE"      ],
    ["aOffi"     ,"OFFI"      ],
    ["aGved"     ,"GVED"      ],
    ["aHlth"     ,"HLTH"      ],
    ["aOthr"     ,"OTHR"      ],
    ["aAgri"     ,"AGRI"      ],
    ["aMing"     ,"MING"      ],
    ["aCons"     ,"CONS"      ],
    ["aHbj"      ,"HBJ"       ],
    ["aAvgInc"   ,"AVGINCOME" ],
    ["aEnrolElem","ENROL_ELEM"],
    ["aEnrolMidl","ENROL_MIDL"],
    ["aEnrolHigh","ENROL_HIGH"]
], columns=('col','aCode'))

display(dfColKeys)
# Out:
#          aCode                            aName
# 0        TOTHH                 Total Households
# 1        HHPOP             Household Population
# 2       HHSIZE                   Household Size
# 3       TOTEMP               Typical Employment
# 4       RETEMP                Retail Employment
# 5       INDEMP            Industrial Employment
# 6       OTHEMP                 Other Employment
# 7       ALLEMP                   All Employment
# 8         RETL         Retail Employment (RETL)
# 9         FOOD                  Food Employment
# 10        MANU         Manufacturing Employment
# 11        WSLE             Wholesale Employment
# 12        OFFI                Office Employment
# 13        GVED  Government/Education Employment
# 14        HLTH                Health Employment
# 15        OTHR                 Other Employment
# 16        AGRI          Agricultural Employment
# 17        MING                Mining Employment
# 18        CONS          Construction Employment
# 19         HBJ        Home-Based Job Employment
# 20   AVGINCOME                   Average Income
# 21  ENROL_ELEM     Elementary School Enrollment
# 22  ENROL_MIDL         Middle School Enrollment
# 23  ENROL_HIGH           High School Enrollment
# Empty DataFrame
# Columns: [fCode, fName, fWidget, fOwnCol]
# Index: []
# []
#            col       aCode
# 0          aHh       TOTHH
# 1         aPop       HHPOP
# 2      aHhsize      HHSIZE
# 3      aTotEmp      TOTEMP
# 4      aRetEmp      RETEMP
# 5      aIndEmp      INDEMP
# 6      aOthEmp      OTHEMP
# 7      aAllEmp      ALLEMP
# 8     aRetlEmp        RETL
# 9     aFoodEmp        FOOD
# 10    aManuEmp        MANU
# 11    aWsleEmp        WSLE
# 12    aOffiEmp        OFFI
# 13    aGvedEmp        GVED
# 14    aHlthEmp        HLTH
# 15    aOthrEmp        OTHR
# 16    aAgriEmp        AGRI
# 17    aMingEmp        MING
# 18    aConsEmp        CONS
# 19        aHbj         HBJ
# 20     aAvgInc   AVGINCOME
# 21  aEnrolElem  ENROL_ELEM
# 22  aEnrolMidl  ENROL_MIDL
# 23  aEnrolHigh  ENROL_HIGH

# %%
dfScn = pd.read_json(scnJson)
dfScn = dfScn[['modVersion','scnGroup','scnYear']]
display(dfScn)
display(dfScn.dtypes)
# Out:
#    modVersion   scnGroup  scnYear
# 0        v900       Base     2019
# 1        v900       Base     2023
# 2        v900        TIP     2028
# 3        v900        RTP     2032
# 4        v900        RTP     2042
# 5        v900        RTP     2050
# 6        v900    NoBuild     2032
# 7        v900    NoBuild     2042
# 8        v900    NoBuild     2050
# 9        v900      Needs     2032
# 10       v900      Needs     2042
# 11       v900      Needs     2050
# 12       v900  Needs MAG     2050
# modVersion    object
# scnGroup      object
# scnYear        int64
# dtype: object

# %%
# create folders
# Define a root directory where you want to create subfolders
root_dir = './_site/data/scnData'

# Ensure the root directory exists
if not os.path.exists(root_dir):
    os.makedirs(root_dir)

# Loop through the dataframe and create subfolders
for index, row in dfScn.iterrows():
    folder_name = f"{row['modVersion']}__{row['scnGroup']}__{row['scnYear']}"
    full_path = os.path.join(root_dir, folder_name)
    
    if not os.path.exists(full_path):
        os.makedirs(full_path)

# %%
import pandas as pd
import os
import glob

# Define the subfolder path
subfolder_path = r'E:\GitHub\WF-TDM-v9x\_working-bill\results'

# Create an empty list to store dataframes
_dfs = []

# Iterate through the scenarios
for _, row in dfScn.iterrows():
    print(row['scnGroup'] + '_' + str(row['scnYear']))
    
    # Read the CSV into a dataframe
    _df = pd.read_csv(os.path.join(subfolder_path, row['scnGroup'] + '_' + str(row['scnYear']) + '_ZoneSummary_TripsAndModeShare.csv'))
    #display(_df)

    _df_melt = _df.melt(id_vars=['TAZID'] + lstFiltersOwnCol, value_vars=dfColKeys['col'].tolist(), var_name='col', value_name='val')
    #display(_df_melt)
    _df_melt_withkeys = pd.DataFrame.merge(_df_melt, dfColKeys, on='col')
    #display(_df_melt_withkeys)

    _df_melt_withkeys_pivot_atts = _df_melt_withkeys.pivot(index=[col for col in _df_melt_withkeys.columns if col not in ['aCode','val','col']], columns='aCode', values="val")
    _df_melt_withkeys_pivot_atts.columns.name = None
    _df_melt_withkeys_pivot_atts.reset_index(inplace=True)
    _df_melt_withkeys_pivot_atts
    #display(_df_melt_withkeys_pivot_atts)

    # Add new columns with values from filename
    _df_melt_withkeys_pivot_atts['modVersion'] = row['modVersion']
    _df_melt_withkeys_pivot_atts['scnGroup'] = row['scnGroup']
    _df_melt_withkeys_pivot_atts['scnYear'] = row['scnYear']

    _df_melt_withkeys_pivot_atts['scnYear'] = _df_melt_withkeys_pivot_atts['scnYear'].astype('int64')

    _df_melt_withkeys_pivot_atts

    _dfs.append(_df_melt_withkeys_pivot_atts)

# If you want to concatenate all the dataframes into a single dataframe
print('combining dataframes...')
dfCombined_melt_withkeys_pivot_atts = pd.concat(_dfs, ignore_index=True)
display(dfCombined_melt_withkeys_pivot_atts)
print('Done!')
# Out:
# Base_2019
# Base_2023
# TIP_2028
# RTP_2032
# RTP_2042
# RTP_2050
# NoBuild_2032
# NoBuild_2042
# NoBuild_2050
# Needs_2032
# Needs_2042
# Needs_2050
# Needs_2042
# Needs MAG_2050
# combining dataframes...
#           TAZID    fPurp fMode fTod fPA   aSAll   aSAut  aSBik  aSBrt  aSCor  \
# 0             2  AllPurp   All   Dy   A  0.0000  0.0000    0.0    0.0    0.0
# 1             2  AllPurp   All   Dy   P  0.0000  0.0000    0.0    0.0    0.0
# 2             2  AllPurp   All   Ok   A  0.0000  0.0000    0.0    0.0    0.0
# 3             2  AllPurp   All   Ok   P  0.0000  0.0000    0.0    0.0    0.0
# 4             2  AllPurp   All   Pk   A  0.0000  0.0000    0.0    0.0    0.0
# ...         ...      ...   ...  ...  ..     ...     ...    ...    ...    ...
# 29008935   3629      HBW  sr3p   Dy   P  0.0797  0.0812    0.0    0.0    0.0
# 29008936   3629      HBW  sr3p   Ok   A  0.0000  0.0000    0.0    0.0    0.0
# 29008937   3629      HBW  sr3p   Ok   P  0.0455  0.0459    0.0    0.0    0.0
# 29008938   3629      HBW  sr3p   Pk   A  0.0000  0.0000    0.0    0.0    0.0
# 29008939   3629      HBW  sr3p   Pk   P  0.0978  0.1003    0.0    0.0    0.0
#
#           ...  aSLcl  aSLrt   aSMot  aSNon  aSTrn  aSWlk   aT  modVersion  \
# 0         ...    0.0    0.0  0.0000    0.0    0.0    0.0   39        v900
# 1         ...    0.0    0.0  0.0000    0.0    0.0    0.0  145        v900
# 2         ...    0.0    0.0  0.0000    0.0    0.0    0.0   26        v900
# 3         ...    0.0    0.0  0.0000    0.0    0.0    0.0   92        v900
# 4         ...    0.0    0.0  0.0000    0.0    0.0    0.0   13        v900
# ...       ...    ...    ...     ...    ...    ...    ...  ...         ...
# 29008935  ...    0.0    0.0  0.0797    0.0    0.0    0.0   25        v900
# 29008936  ...    0.0    0.0  0.0000    0.0    0.0    0.0    0        v900
# 29008937  ...    0.0    0.0  0.0455    0.0    0.0    0.0    5        v900
# 29008938  ...    0.0    0.0  0.0000    0.0    0.0    0.0    0        v900
# 29008939  ...    0.0    0.0  0.0978    0.0    0.0    0.0   20        v900
#
#            scnGroup scnYear
# 0              Base    2019
# 1              Base    2019
# 2              Base    2019
# 3              Base    2019
# 4              Base    2019
# ...             ...     ...
# 29008935  Needs MAG    2050
# 29008936  Needs MAG    2050
# 29008937  Needs MAG    2050
# 29008938  Needs MAG    2050
# 29008939  Needs MAG    2050
#
# [29008940 rows x 22 columns]
# Done!

# %%
# Out:
#           TAZID    fPurp fMode fTod fPA  aShAll  aShAut  aShBik  aShBrt  \
# 0             2  AllPurp   All   Dy   A  0.0000  0.0000     0.0     0.0
# 1             2  AllPurp   All   Dy   P  0.0000  0.0000     0.0     0.0
# 2             2  AllPurp   All   Ok   A  0.0000  0.0000     0.0     0.0
# 3             2  AllPurp   All   Ok   P  0.0000  0.0000     0.0     0.0
# 4             2  AllPurp   All   Pk   A  0.0000  0.0000     0.0     0.0
# ...         ...      ...   ...  ...  ..     ...     ...     ...     ...
# 29008935   3629      HBW  sr3p   Dy   P  0.0797  0.0812     0.0     0.0
# 29008936   3629      HBW  sr3p   Ok   A  0.0000  0.0000     0.0     0.0
# 29008937   3629      HBW  sr3p   Ok   P  0.0455  0.0459     0.0     0.0
# 29008938   3629      HBW  sr3p   Pk   A  0.0000  0.0000     0.0     0.0
# 29008939   3629      HBW  sr3p   Pk   P  0.0978  0.1003     0.0     0.0
#
#           aShCor  ...  aShLcl  aShLrt  aShMot  aShNon  aShTrn  aShWlk  aTrips  \
# 0            0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0      39
# 1            0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0     145
# 2            0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0      26
# 3            0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0      92
# 4            0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0      13
# ...          ...  ...     ...     ...     ...     ...     ...     ...     ...
# 29008935     0.0  ...     0.0     0.0  0.0797     0.0     0.0     0.0      25
# 29008936     0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0       0
# 29008937     0.0  ...     0.0     0.0  0.0455     0.0     0.0     0.0       5
# 29008938     0.0  ...     0.0     0.0  0.0000     0.0     0.0     0.0       0
# 29008939     0.0  ...     0.0     0.0  0.0978     0.0     0.0     0.0      20
#
#           modVersion   scnGroup scnYear
# 0               v900       Base    2019
# 1               v900       Base    2019
# 2               v900       Base    2019
# 3               v900       Base    2019
# 4               v900       Base    2019
# ...              ...        ...     ...
# 29008935        v900  Needs MAG    2050
# 29008936        v900  Needs MAG    2050
# 29008937        v900  Needs MAG    2050
# 29008938        v900  Needs MAG    2050
# 29008939        v900  Needs MAG    2050
#
# [29008940 rows x 22 columns]

# %%
## replace zeros with NaN
#import numpy as np
#dfCombined_melt_withkeys_pivot_atts.replace(0, np.nan, inplace=True)
#display(dfCombined_melt_withkeys_pivot_atts)

# %%
import json

# PREPARE JSON FOR EACH SCENARIO
# scenarioDetails
# attributes
#   aCode
#   aName
#   filterGroup
# filterGroups
#   possible filterGroup Options
#   for each filterGroup possibility, the data for that selection

_df0 = dfCombined_melt_withkeys_pivot_atts.copy()

# Loop through scenarios in dfScn
for _, row in dfScn.iterrows():

    _scenarioCode = row['modVersion'] + '__' + row['scnGroup'] + '__' + str(row['scnYear'])
    print(_scenarioCode)

    # format scenario details for json export
    jsonScenarioDetails = row.to_dict()

    #print(row['modVersion'] + row['scnGroup'] + str(row['scnYear']))
    # Filter the main dataframe based on the scenario
    _df0_filtered = _df0[
        (_df0['modVersion'] == row['modVersion']) & 
        (_df0['scnGroup'] == row['scnGroup']) & 
        (_df0['scnYear'] == row['scnYear'])
    ].copy()

    _df = _df0_filtered.copy()
    #display(_df)

    # add options to _dfFiltersWithOptions
    
    _dfFiltersWithOptions = dfFilters.copy()

    # For each fCode, get the unique values from dfData, and join to dfFilters
    formatted_lists = []
    for fCode in dfFilters['fCode']:
        unique_values = [x for x in _df[fCode].unique() if pd.notna(x)]
        formatted_lists.append(unique_values)
    #display (formatted_lists)

    _dfFiltersWithOptions['fOptions'] = formatted_lists    
    #display(_dfFiltersWithOptions)

    # get list of fitler groups (any column that begins with f)
    fCols = [col for col in dfCombined_melt_withkeys_pivot_atts.columns if col.startswith('f')]
    _df[fCols] = _df[fCols].fillna('')
    _dfFilters = _df[fCols].drop_duplicates()

    # Drop rows with empty strings in ALL columns
    #_dfFilters = _dfFilters[~(_dfFilters == '').all(axis=1)]
    #display(_dfFilters)

    # Convert the values to binary form, so 1 where there is a value and 0 elsewhere
    binary_dfFilters = _dfFilters.applymap(lambda x: 0 if x=='' else 1)
    #display(binary_dfFilters)

    # Get unique rows of combinations
    unique_combinations = binary_dfFilters.drop_duplicates()

    # Convert the unique combinations to a list of tuples
    lstCombinations = list(unique_combinations.itertuples(index=False, name=None))
    #display(lstCombinations)

    # Define a function to convert to binary
    def is_empty_or_not(value):
        return 0 if value=='' else 1

    _dfFilterACodes = pd.DataFrame()

    jsonDataCombined = {}

    # loop through all combinations in list
    for combination in lstCombinations:

        # get list of column names with a 1 for given combination
        _dfFilterColsWithValue1 = [col for idx, col in enumerate(fCols) if combination[idx] == 1]
        #display(_dfFilterColsWithValue1)

        # create string of column names
        _strFilterGroup = '_'.join(_dfFilterColsWithValue1)
        #display(_strFilterGroup)
        
        # Initialize the condition as True for all rows
        condition = pd.Series([True] * len(_df), index=_df.index)

        # Apply the condition programmatically for each column in the list
        for col, comb_value in zip(fCols, combination):
            condition &= _df[col].apply(is_empty_or_not) == comb_value

        _filtered_df = _df[condition].copy()
        _filtered_df.drop(columns=['modVersion','scnGroup','scnYear'], inplace=True)
        #display(_filtered_df)

        # Remove columns where all values are NaN
        _filtered_df_noNA = _filtered_df.dropna(axis=1, how='all')
        #display(_filtered_df_noNA)

        _fColsToDrop = [col for col in _filtered_df_noNA.columns if col.startswith('f') and (_filtered_df_noNA[col] == '').all()]

        # Drop the identified columns - only have fCols with values
        _df2 = _filtered_df_noNA.drop(columns=_fColsToDrop)
        #display(_df2)

        # Get list of columns that begin with "a", create a dataframe the filter group for all possible combinations
        aCols = [col for col in _filtered_df_noNA.columns if col.startswith('a')]
        new_data = pd.DataFrame([{"filterGroup": _strFilterGroup, 'aCode': aCols}])
        new_data = new_data.explode('aCode').reset_index(drop=True)
        _dfFilterACodes = pd.concat([_dfFilterACodes, new_data], ignore_index=True)

        # get unique filter values
        _fColsRemain = [col for col in _df2.columns if col.startswith('f')]
        #display(_fColsRemain)
        if _fColsRemain:
            _dfFilterOptions = _df2[_fColsRemain].drop_duplicates()
        else:
            # add dummy row for no filter
            _dfFilterOptions = pd.DataFrame({'nofilter': ['']})

        #display(_dfFilterOptions)

        # Handle no filter data

        first_row = True

        for index, row in _dfFilterOptions.iterrows():

            _filterRowIndex = '_'.join(row.astype(str).values)

            print(_filterRowIndex)
            
            final_condition = ""

            if _fColsRemain != []:
                # Dynamically construct the filter condition
                shared_columns = set(_dfFilterOptions.columns) & set(_df2.columns)
                conditions = (_df2[col].isin([row[col]]) for col in shared_columns)
                final_condition = next(conditions)

                for condition in conditions:
                    final_condition &= condition

                filtered_df2 = _df2[final_condition].copy()
                filtered_df2.drop(columns=_fColsRemain, inplace=True)
            else: # no filter condition
                filtered_df2 =  _df2

            _df2noI = filtered_df2.reset_index()

            jsonDataForFilterOption = {}

            for index, row in _df2noI.iterrows():
                # Initialize an empty dictionary for the row
                row_dict = {}

                # Loop through each column that starts with 'a'
                for col in _df2noI.columns[_df2noI.columns.str.startswith('a')]:
                    # Add to row_dict if value is greater than 0
                    if row[col] > 0:
                        row_dict[col] = row[col]
                
                # If row_dict is not empty, add it to jsonDataCombined with TAZID as the key
                if row_dict:
                    jsonDataForFilterOption[int(row['TAZID'])] = row_dict  # Cast TAZID to int
            
            # Encapsulate jsonDataCombined under the _filterRowIndex
            final_json = {_filterRowIndex: jsonDataForFilterOption}

            ## Convert to a JSON formatted string
            #json_output = json.dumps(final_json)

            # Append the JSON structure from this iteration to the combined
            jsonDataCombined = {**jsonDataCombined, **final_json}

    _dfAttributesWFilter = pd.DataFrame.merge(dfAttributes, _dfFilterACodes, on='aCode')
    jsonAttributes = _dfAttributesWFilter.to_dict(orient='records')
    jsonFilters = _dfFiltersWithOptions.to_dict(orient='records')

    # Construct final JSON structure
    jsonScenario = {
        'scenarioDetails': jsonScenarioDetails,
        'attributes': jsonAttributes,
        'filters': jsonFilters,
        'data': jsonDataCombined#,
        #'aggregations': aggregations_list
    }

    # Specify the desired file name
    filename = '_site/data/scnData/' + _scenarioCode + '/' + outputJsonName

    # Open the file in write mode
    with open(filename, 'w') as file:
        json.dump(jsonScenario, file)
# Out:
# v900__Base__2019
# "filterSelection": {"fPurp":"AllPurp","fMode":"All","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"All","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"All","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"All","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"All","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"All","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Aut","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Aut","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Aut","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Aut","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Aut","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Aut","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Bik","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Bik","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Bik","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Bik","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Bik","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Bik","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Mot","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Mot","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Mot","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Mot","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Mot","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Mot","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Non","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Non","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Non","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Non","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Non","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Non","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Wlk","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Wlk","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Wlk","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Wlk","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Wlk","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"Wlk","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"da","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"da","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"da","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"da","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"da","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"da","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsBk","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsBk","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsBk","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsBk","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsBk","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsBk","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsWk","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsWk","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsWk","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsWk","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsWk","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"nsWk","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr2","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr2","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr2","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr2","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr2","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr2","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr3p","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr3p","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr3p","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr3p","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr3p","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"AllPurp","fMode":"sr3p","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"All","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"All","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"All","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"All","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"All","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"All","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Aut","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Aut","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Aut","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Aut","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Aut","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Aut","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Bik","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Bik","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Bik","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Bik","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Bik","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Bik","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Mot","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Mot","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Mot","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Mot","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Mot","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Mot","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Non","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Non","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Non","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Non","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Non","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Non","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Wlk","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Wlk","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Wlk","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Wlk","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"Wlk","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"Wlk","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"da","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"da","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"da","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"da","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"da","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"da","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsBk","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsBk","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsBk","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsBk","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsBk","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsBk","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsWk","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsWk","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsWk","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsWk","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsWk","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"nsWk","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr2","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr2","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr2","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr2","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr2","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr2","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr3p","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr3p","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr3p","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr3p","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr3p","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBO","fMode":"sr3p","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"All","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"All","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"All","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"All","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"All","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"All","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Aut","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Aut","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Aut","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Aut","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Aut","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Aut","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Mot","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Mot","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Mot","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Mot","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Mot","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"Mot","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scDp","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scDp","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scDp","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scDp","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scDp","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scDp","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scSf","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scSf","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scSf","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scSf","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scSf","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBSch","fMode":"scSf","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"All","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"All","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"All","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"All","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"All","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"All","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Aut","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Aut","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Aut","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Aut","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Aut","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Aut","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Bik","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Bik","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Bik","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Bik","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Bik","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Bik","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Mot","fTod":"Dy","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Mot","fTod":"Dy","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Mot","fTod":"Ok","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Mot","fTod":"Ok","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"Mot","fTod":"Pk","fPA":"A"}
# "filterSelection": {"fPurp":"HBW","fMode":"Mot","fTod":"Pk","fPA":"P"}
# "filterSelection": {"fPurp":"HBW","fMode":"
aT": 292.0}, "192": {"aT": 8.0}, "193": {"aT": 462.0}, "195": {"aT": 212.0}, "196": {"aT": 327.0}, "197": {"aT": 346.0}, "198": {"aT": 89.0}, "199": {"aT": 1.0}, "200": {"aT": 190.0}, "201": {"aT": 87.0}, "202": {"aT": 87.0}, "203": {"aT": 291.0}, "204": {"aT": 237.0}, "205": {"aT": 325.0}, "206": {"aT": 162.0}, "207": {"aT": 73.0}, "208": {"aT": 211.0}, "209": {"aT": 123.0}, "210": {"aT": 49.0}, "211": {"aT": 24.0}, "212": {"aT": 408.0}, "213": {"aT": 3460.0}, "214": {"aT": 1201.0}, "215": {"aT": 532.0}, "216": {"aT": 298.0}, "217": {"aT": 613.0}, "218": {"aT ...

# %%
import json
import pandas as pd

_df2noI = filtered_df2.reset_index()
df = _df2noI

jsonDataCombined = {}

for index, row in df.iterrows():
    # Initialize an empty dictionary for the row
    row_dict = {}

    # Loop through each column that starts with 'a'
    for col in df.columns[df.columns.str.startswith('a')]:
        # Add to row_dict if value is greater than 0
        if row[col] > 0:
            row_dict[col] = row[col]
    
    # If row_dict is not empty, add it to jsonDataCombined with TAZID as the key
    if row_dict:
        jsonDataCombined[int(row['TAZID'])] = row_dict  # Cast TAZID to int

# Convert to a JSON formatted string
json_output = json.dumps(jsonDataCombined, indent=4)

print(json_output)
# Out:
# {
#     "2": {
#         "aT": 39.0
#     },
#     "3": {
#         "aT": 40.0
#     },
#     "4": {
#         "aT": 8.0
#     },
#     "5": {
#         "aT": 188.0
#     },
#     "6": {
#         "aT": 19.0
#     },
#     "7": {
#         "aT": 322.0
#     },
#     "8": {
#         "aT": 350.0
#     },
#     "9": {
#         "aT": 136.0
#     },
#     "10": {
#         "aT": 162.0
#     },
#     "11": {
#         "aT": 8.0
#     },
#     "12": {
#         "aT": 43.0
#     },
#     "15": {
#         "aT": 344.0
#     },
#     "16": {
#         "aT": 152.0
#     },
#     "17": {
#         "aT": 13.0
#     },
#     "18": {
#         "aT": 832.0
#     },
#     "19": {
#         "aT": 737.0
#     },
#     "20": {
#         "aT": 691.0
#     },
#     "21": {
#         "aT": 519.0
#     },
#     "22": {
#         "aT": 16.0
#     },
#     "23": {
#         "aT": 67.0
#     },
#     "24": {
#         "aT": 337.0
#     },
#     "25": {
#         "aT": 1712.0
#     },
#     "26": {
#         "aT": 1399.0
#     },
#     "28": {
#         "aT": 107.0
#     },
#     "29": {
#         "aT": 528.0
#     },
#     "30": {
#         "aT": 1480.0
#     },
#     "31": {
#         "aT": 1543.0
#     },
#     "32": {
#         "aT": 396.0
#     },
#     "33": {
#         "aT": 516.0
#     },
#     "34": {
#         "aT": 694.0
#     },
#     "35": {
#         "aT": 944.0
#     },
#     "36": {
#         "aT": 295.0
#     },
#     "37": {
#         "aT": 14.0
#     },
#     "38": {
#         "aT": 1860.0
#     },
#     "39": {
#         "aT": 696.0
#     },
#     "40": {
#         "aT": 2354.0
#     },
#     "41": {
#         "aT": 2606.0
#     },
#     "42": {
#         "aT": 444.0
#     },
#     "43": {
