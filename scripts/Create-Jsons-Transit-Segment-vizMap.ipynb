# %%
import pandas as pd
import os

# %%
segSummaries =  '../data/transitSummaries/segments'
scnJson = '../_site/scenarios.json'
outputJsonName = 'transit-segments-riders'
# Define the subfolder path
subfolder_path = '../data/transitSummaries/segments'

# %%
# If there are duplicate keys, should they be added, or just give error
# USE CAUTIOUSLY, SINCE TDM OUTPUT SHOULD BE ONLY HAVING ONE RECORD PER KEY
# SO THIS SHOULD BE A TEMPORARY FIX
bAddDuplicates = False

bFillFilterNAWithTextNA = True

# id variables 
lstIdVars = ['SegID']

# aCode: Code name of attribute. Must begin with lowercase 'a'
# aName: Display name of the attribute
# aRound: how many decimals

# attributes for road seg summaries
dfAttributes = pd.DataFrame([
    ["aR","Riders" , 2],
    ["aH","Headway", 0],
    ["aS","Speed"  , 0]
], columns=('aCode','aName', 'aRound'))

display(dfAttributes)


# fCode: Code name of filter. Must begin with lowercase 'f'
# fName: Display name of the filter
# fWidget: what type of widget should the web app use... NOT SURE IF THIS IS USED OR OVERRIDDEN LATER ON
# fOwnCol: True if filter is already a column (long format)
# col: column name in data of filter, only used if fOwnCol==True

dfFilters = pd.DataFrame([
    ["fPurp" ,"Trip Purpose"     , "combobox", True, 'Purpose'   ],
    ["fTod"  ,"Time of Day"      , "combobox", True, 'Period'    ],
    ["fMdA"  ,"Access Mode"      , "combobox", True, 'AccessMode'],
    ["fDir"  ,"Inbound/Outbound" , "combobox", True, 'IB_OB'     ],
    ["fMd"   ,"Mode"             , "combobox", True, 'Mode'      ],
    ["fName" ,"Route Name"       , "combobox", True, 'Name'      ],
    ["fMdH"  ,"Hierarchical Mode", "select"  , False, None       ]
], columns=('fCode','fName','fWidget','fOwnCol','col'))

lstFiltersOwnCol = dfFilters[dfFilters['fOwnCol'] == True]['fCode'].tolist()
display(lstFiltersOwnCol)

display(dfFilters)

# MAKE SURE ONLY COLUMNS WITH LOWER-CASE "f" ARE FILTER COLUMNS AND LOWER-CASE "a" ARE ATTRIBUTE COLUMNS
# aCode must match value in dfAttributes

dfColKeys = pd.DataFrame([
    ['Riders'      , 'ALL', 'aR'],
    ['FromSkim_LCL', 'LCL', 'aR'],
    ['FromSkim_COR', 'COR', 'aR'],
    ['FromSkim_BRT', 'BRT', 'aR'],
    ['FromSkim_EXP', 'EXP', 'aR'],
    ['FromSkim_LRT', 'LRT', 'aR'],
    ['FromSkim_CRT', 'CRT', 'aR'],
    ['Headway'     ,  None, 'aH'],
    ['Speed'       ,  None, 'aS']
], columns=('col','fMdH','aCode'))

display(dfColKeys)

##### oweropwejrl:kjwerl:mkelwkjwer:
dfRepetitiveColKeysWithActualFilters = pd.DataFrame([
    [['aH','aS'], ["fDir","fTod","fMd","fName"]]
], columns=('aCodes','filters'))

display(dfRepetitiveColKeysWithActualFilters)
# Out:
#   aCode    aName  aRound
# 0    aR   Riders       2
# 1    aH  Headway       0
# 2    aS    Speed       0
# ['fPurp', 'fTod', 'fMdA', 'fDir', 'fMd', 'fName']
#    fCode              fName   fWidget  fOwnCol         col
# 0  fPurp       Trip Purpose  combobox     True     Purpose
# 1   fTod        Time of Day  combobox     True      Period
# 2   fMdA        Access Mode  combobox     True  AccessMode
# 3   fDir   Inbound/Outbound  combobox     True       IB_OB
# 4    fMd               Mode  combobox     True        Mode
# 5  fName         Route Name  combobox     True        Name
# 6   fMdH  Hierarchical Mode    select    False        None
#             col  fMdH aCode
# 0        Riders   ALL    aR
# 1  FromSkim_LCL   LCL    aR
# 2  FromSkim_COR   COR    aR
# 3  FromSkim_BRT   BRT    aR
# 4  FromSkim_EXP   EXP    aR
# 5  FromSkim_LRT   LRT    aR
# 6  FromSkim_CRT   CRT    aR
# 7       Headway  None    aH
# 8         Speed  None    aS
#      aCodes                   filters
# 0  [aH, aS]  [fDir, fTod, fMd, fName]

# %%
dfScn = pd.read_json(scnJson)
dfScn = dfScn[['modVersion','scnGroup','scnYear']]
display(dfScn)
# Out:
#    modVersion   scnGroup  scnYear
# 0        v900       Base     2019
# 1        v900       Base     2023
# 2        v900        TIP     2028
# 3        v900        RTP     2032
# 4        v900        RTP     2042
# 5        v900        RTP     2050
# 6        v900    NoBuild     2032
# 7        v900    NoBuild     2042
# 8        v900    NoBuild     2050
# 9        v900      Needs     2032
# 10       v900      Needs     2042
# 11       v900      Needs     2050
# 12       v900  Needs MAG     2050

# %%
# create folders
# Define a root directory where you want to create subfolders
root_dir = '../_site/data/scnData'

# Ensure the root directory exists
if not os.path.exists(root_dir):
    os.makedirs(root_dir)

# Loop through the dataframe and create subfolders
for index, row in dfScn.iterrows():
    folder_name = f"{row['modVersion']}__{row['scnGroup']}__{row['scnYear']}"
    full_path = os.path.join(root_dir, folder_name)
    
    if not os.path.exists(full_path):
        os.makedirs(full_path)
        print('Making directory: ' + full_path)
    else:
        print('Directory already made: ' + full_path)
# Out:
# Directory already made: ../_site/data/scnData\v900__Base__2019
# Directory already made: ../_site/data/scnData\v900__Base__2023
# Directory already made: ../_site/data/scnData\v900__TIP__2028
# Directory already made: ../_site/data/scnData\v900__RTP__2032
# Directory already made: ../_site/data/scnData\v900__RTP__2042
# Directory already made: ../_site/data/scnData\v900__RTP__2050
# Directory already made: ../_site/data/scnData\v900__NoBuild__2032
# Directory already made: ../_site/data/scnData\v900__NoBuild__2042
# Directory already made: ../_site/data/scnData\v900__NoBuild__2050
# Directory already made: ../_site/data/scnData\v900__Needs__2032
# Directory already made: ../_site/data/scnData\v900__Needs__2042
# Directory already made: ../_site/data/scnData\v900__Needs__2050
# Directory already made: ../_site/data/scnData\v900__Needs MAG__2050

# %%
import pandas as pd
import os
import glob

# Create an empty list to store dataframes
_dfs = []

# Iterate through the scenarios
for _, row in dfScn.iterrows():
    print(row['scnGroup'] + '__' + str(row['scnYear']))
    
    # Read the CSV into a dataframe
    _df = pd.read_csv(os.path.join(subfolder_path, row['modVersion'] + '__' + row['scnGroup'] + '__' + str(row['scnYear']) + ".csv"))
    #display(_df)

    # rename filters that are their own columns

    # Create a dictionary for renaming columns
    rename_dict = dfFilters[dfFilters['fOwnCol']==True].set_index('col')['fCode'].dropna().to_dict()

    # Renaming columns in '_df' using the dictionary
    _df.rename(columns=rename_dict, inplace=True)

    _df_melt = _df.melt(id_vars=lstIdVars + lstFiltersOwnCol, value_vars=dfColKeys['col'].tolist(), var_name='col', value_name='val')
    #display(_df_melt)
    _df_melt_withkeys = pd.DataFrame.merge(_df_melt, dfColKeys, on='col')
    #display(_df_melt_withkeys)

    # if duplicates then add the values together... NEED TO MAKE SURE THIS SHOULD BE DONE FIRST
    if bAddDuplicates:
        _df_melt_withkeys = _df_melt_withkeys.groupby([col for col in _df_melt_withkeys.columns if col not in ['val']],as_index=False).sum()

    _df_melt_withkeys_pivot_atts = _df_melt_withkeys.pivot(index=[col for col in _df_melt_withkeys.columns if col not in ['aCode','val','col']], columns='aCode', values="val")
    _df_melt_withkeys_pivot_atts.columns.name = None
    _df_melt_withkeys_pivot_atts.reset_index(inplace=True)
    _df_melt_withkeys_pivot_atts
    #display(_df_melt_withkeys_pivot_atts)

    # Add new columns with values from filename
    _df_melt_withkeys_pivot_atts['modVersion'] = row['modVersion']
    _df_melt_withkeys_pivot_atts['scnGroup'] = row['scnGroup']
    _df_melt_withkeys_pivot_atts['scnYear'] = row['scnYear']

    _df_melt_withkeys_pivot_atts['scnYear'] = _df_melt_withkeys_pivot_atts['scnYear'].astype('int64')

    _dfs.append(_df_melt_withkeys_pivot_atts)

# If you want to concatenate all the dataframes into a single dataframe
print('combining dataframes...')
dfCombined_melt_withkeys_pivot_atts = pd.concat(_dfs, ignore_index=True)


# round aCode columns

# Creating a dictionary to map column names to their rounding values
rounding_dict = dict(zip(dfAttributes['aCode'], dfAttributes['aRound']))

# Rounding the columns based on the mapping
for col, round_val in rounding_dict.items():
    if col in dfCombined_melt_withkeys_pivot_atts.columns:
        dfCombined_melt_withkeys_pivot_atts[col] = dfCombined_melt_withkeys_pivot_atts[col].round(round_val)

# fill NA with 'N/A'
if bFillFilterNAWithTextNA:
    dfCombined_melt_withkeys_pivot_atts[[col for col in dfCombined_melt_withkeys_pivot_atts.columns if col.startswith('f')]] = dfCombined_melt_withkeys_pivot_atts[[col for col in dfCombined_melt_withkeys_pivot_atts.columns if col.startswith('f')]].fillna('N/A')

display(dfCombined_melt_withkeys_pivot_atts)

print('Done!')
# Out:
# Base__2019
# Base__2023
# TIP__2028
# RTP__2032
# RTP__2042
# RTP__2050
# NoBuild__2032
# NoBuild__2042
# NoBuild__2050
# Needs__2032
# Needs__2042
# Needs__2050
# Needs MAG__2050
# combining dataframes...
#               SegID fPurp fTod   fMdA fDir  fMd           fName fMdH    aH  \
# 0        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  N/A  60.0
# 1        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  ALL   NaN
# 2        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  BRT   NaN
# 3        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  COR   NaN
# 4        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  CRT   NaN
# ...             ...   ...  ...    ...  ...  ...             ...  ...   ...
# 1644619   WFRC_8266   All   pk   walk   OB  7.0          Orange  COR   NaN
# 1644620   WFRC_8266   All   pk   walk   OB  7.0          Orange  CRT   NaN
# 1644621   WFRC_8266   All   pk   walk   OB  7.0          Orange  EXP   NaN
# 1644622   WFRC_8266   All   pk   walk   OB  7.0          Orange  LCL   NaN
# 1644623   WFRC_8266   All   pk   walk   OB  7.0          Orange  LRT   NaN
#
#              aR    aS modVersion   scnGroup  scnYear
# 0           NaN  33.0       v900       Base     2019
# 1           0.0   NaN       v900       Base     2019
# 2           0.0   NaN       v900       Base     2019
# 3           0.0   NaN       v900       Base     2019
# 4           0.0   NaN       v900       Base     2019
# ...         ...   ...        ...        ...      ...
# 1644619     0.0   NaN       v900  Needs MAG     2050
# 1644620  2933.9   NaN       v900  Needs MAG     2050
# 1644621     0.0   NaN       v900  Needs MAG     2050
# 1644622     0.0   NaN       v900  Needs MAG     2050
# 1644623  1666.0   NaN       v900  Needs MAG     2050
#
# [1644624 rows x 14 columns]
# Done!

# %%
dfTest = dfCombined_melt_withkeys_pivot_atts[(dfCombined_melt_withkeys_pivot_atts['SegID']=='0006_158.5') & (dfCombined_melt_withkeys_pivot_atts['fName']=='M805_Santaquin')]
dfTest
# Out:
#               SegID fPurp fTod   fMdA fDir  fMd           fName fMdH    aH  \
# 0        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  N/A  60.0
# 1        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  ALL   NaN
# 2        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  BRT   NaN
# 3        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  COR   NaN
# 4        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  CRT   NaN
# ...             ...   ...  ...    ...  ...  ...             ...  ...   ...
# 1507011  0006_158.5   All   pk   walk   OB  4.0  M805_Santaquin  COR   NaN
# 1507012  0006_158.5   All   pk   walk   OB  4.0  M805_Santaquin  CRT   NaN
# 1507013  0006_158.5   All   pk   walk   OB  4.0  M805_Santaquin  EXP   NaN
# 1507014  0006_158.5   All   pk   walk   OB  4.0  M805_Santaquin  LCL   NaN
# 1507015  0006_158.5   All   pk   walk   OB  4.0  M805_Santaquin  LRT   NaN
#
#           aR    aS modVersion   scnGroup  scnYear
# 0        NaN  33.0       v900       Base     2019
# 1        0.0   NaN       v900       Base     2019
# 2        0.0   NaN       v900       Base     2019
# 3        0.0   NaN       v900       Base     2019
# 4        0.0   NaN       v900       Base     2019
# ...      ...   ...        ...        ...      ...
# 1507011  0.4   NaN       v900  Needs MAG     2050
# 1507012  0.0   NaN       v900  Needs MAG     2050
# 1507013  0.0   NaN       v900  Needs MAG     2050
# 1507014  1.0   NaN       v900  Needs MAG     2050
# 1507015  0.0   NaN       v900  Needs MAG     2050
#
# [448 rows x 14 columns]

# %%
dfCombined_melt_withkeys_pivot_atts[dfCombined_melt_withkeys_pivot_atts['aH']>0]
# Out:
#               SegID fPurp fTod   fMdA fDir  fMd           fName fMdH    aH  \
# 0        0006_158.5   All   ok  drive   IB  4.0  M805_Santaquin  N/A  60.0
# 8        0006_158.5   All   ok  drive   OB  4.0  M805_Santaquin  N/A  60.0
# 16       0006_158.5   All   ok   walk   IB  4.0  M805_Santaquin  N/A  60.0
# 24       0006_158.5   All   ok   walk   OB  4.0  M805_Santaquin  N/A  60.0
# 32       0006_158.5   All   pk  drive   IB  4.0  M805_Santaquin  N/A  45.0
# ...             ...   ...  ...    ...  ...  ...             ...  ...   ...
# 1644584   WFRC_8266   All   ok   walk   OB  7.0          Orange  N/A  15.0
# 1644592   WFRC_8266   All   pk  drive   IB  7.0          Orange  N/A  15.0
# 1644600   WFRC_8266   All   pk  drive   OB  7.0          Orange  N/A  15.0
# 1644608   WFRC_8266   All   pk   walk   IB  7.0          Orange  N/A  15.0
# 1644616   WFRC_8266   All   pk   walk   OB  7.0          Orange  N/A  15.0
#
#          aR    aS modVersion   scnGroup  scnYear
# 0       NaN  33.0       v900       Base     2019
# 8       NaN  33.0       v900       Base     2019
# 16      NaN  33.0       v900       Base     2019
# 24      NaN  33.0       v900       Base     2019
# 32      NaN  38.0       v900       Base     2019
# ...      ..   ...        ...        ...      ...
# 1644584 NaN  11.0       v900  Needs MAG     2050
# 1644592 NaN  11.0       v900  Needs MAG     2050
# 1644600 NaN  11.0       v900  Needs MAG     2050
# 1644608 NaN  11.0       v900  Needs MAG     2050
# 1644616 NaN  11.0       v900  Needs MAG     2050
#
# [205578 rows x 14 columns]

# %%
dfRepetitiveColKeysWithActualFilters
# Out:
#      aCodes                   filters
# 0  [aH, aS]  [fDir, fTod, fMd, fName]

# %%
dfCombined_melt_withkeys_pivot_atts.columns
# Out:
# Index(['SegID', 'fPurp', 'fTod', 'fMdA', 'fDir', 'fMd', 'fName', 'fMdH', 'aH',
#        'aR', 'aS', 'modVersion', 'scnGroup', 'scnYear'],
#       dtype='object')

# %%
grouping_columns
# Out:
# ['fTod', 'fDir', 'fMd', 'fName']

# %%
filtered_columns_list = [column for column in dfCombined_melt_withkeys_pivot_atts.columns if column not in filter_columns_to_aggregate_on]
filtered_columns_list
# Out:
# ['SegID',
#  'fPurp',
#  'fMdA',
#  'fMdH',
#  'aH',
#  'aR',
#  'aS',
#  'modVersion',
#  'scnGroup',
#  'scnYear']

# %%
# Out:
# ['SegID',
#  'aH',
#  'aR',
#  'aS',
#  'modVersion',
#  'scnGroup',
#  'scnYear',
#  'fTod',
#  'fDir',
#  'fMd',
#  'fName']

# %%
# remove repetitive values from dfAddColKeysWithFilters

for index, row in dfRepetitiveColKeysWithActualFilters.iterrows():
    print(row['filters'])

    filtered_columns_list = [column for column in dfCombined_melt_withkeys_pivot_atts.columns if not column.startswith('f')]
    all_columns = filtered_columns_list + row['filters']

    grouping_columns = [col for col in all_columns if not col.startswith('a')]

    grouped_df = dfCombined_melt_withkeys_pivot_atts.groupby(grouping_columns,as_index=False).first()

    # Replace values in columns starting with 'f' with None
    for col in grouping_columns:
        if col.startswith('f'):
            grouped_df[col] = None


    display(grouped_df)
# Out:
# ['fDir', 'fTod', 'fMd', 'fName']
#              SegID modVersion scnGroup  scnYear  fDir  fTod   fMd fName fPurp  \
# 0       0006_158.5       v900     Base     2019  None  None  None  None   All
# 1       0006_158.5       v900     Base     2019  None  None  None  None   All
# 2       0006_158.5       v900     Base     2019  None  None  None  None   All
# 3       0006_158.5       v900     Base     2019  None  None  None  None   All
# 4       0006_158.5       v900     Base     2023  None  None  None  None   All
# ...            ...        ...      ...      ...   ...   ...   ...   ...   ...
# 102784   WFRC_8266       v900      RTP     2042  None  None  None  None   All
# 102785   WFRC_8266       v900      RTP     2050  None  None  None  None   All
# 102786   WFRC_8266       v900      RTP     2050  None  None  None  None   All
# 102787   WFRC_8266       v900      RTP     2050  None  None  None  None   All
# 102788   WFRC_8266       v900      RTP     2050  None  None  None  None   All
#
#          fMdA fMdH    aH      aR    aS
# 0       drive  N/A  60.0     0.0  33.0
# 1       drive  N/A  45.0     0.0  38.0
# 2       drive  N/A  60.0     0.0  33.0
# 3       drive  N/A  45.0     0.0  38.0
# 4       drive  N/A  40.0     0.0  38.0
# ...       ...  ...   ...     ...   ...
# 102784  drive  N/A  15.0  6377.8  11.0
# 102785  drive  N/A  15.0     4.2  11.0
# 102786  drive  N/A  15.0     6.8  11.0
# 102787  drive  N/A  15.0  1461.8  11.0
# 102788  drive  N/A  15.0  7696.6  11.0
#
# [102789 rows x 14 columns]

# %%
dfTest2 = grouped_df[(grouped_df['SegID']=='0006_158.5') & (grouped_df['fName']=='M805_Santaquin')]
dfTest2
# Out:
# Empty DataFrame
# Columns: [SegID, modVersion, scnGroup, scnYear, fDir, fTod, fMd, fName, fPurp, fMdA, fMdH, aH, aR, aS]
# Index: []

# %%
grouping_columns
# Out:
# ['fPurp',
#  'fMdA',
#  'SegID',
#  'Direction',
#  'LongName',
#  'Distance',
#  'Time',
#  'Speed',
#  'Headway',
#  'Riders',
#  'FromSkim_LCL',
#  'FromSkim_COR',
#  'FromSkim_BRT',
#  'FromSkim_EXP',
#  'FromSkim_LRT',
#  'FromSkim_CRT']

# %%
import json

# PREPARE JSON FOR EACH SCENARIO
# scenarioDetails
# attributes
#   aCode
#   aName
#   filterGroup
# filterGroups
#   possible filterGroup Options
#   for each filterGroup possibility, the data for that selection

_df0 = dfCombined_melt_withkeys_pivot_atts.copy()

# Loop through scenarios in dfScn
for _, row in dfScn.iterrows():

    _scenarioCode = row['modVersion'] + '__' + row['scnGroup'] + '__' + str(row['scnYear'])
    print(_scenarioCode)

    # format scenario details for json export
    jsonScenarioDetails = row.to_dict()

    #print(row['modVersion'] + row['scnGroup'] + str(row['scnYear']))
    # Filter the main dataframe based on the scenario
    _df0_filtered = _df0[
        (_df0['modVersion'] == row['modVersion']) & 
        (_df0['scnGroup'] == row['scnGroup']) & 
        (_df0['scnYear'] == row['scnYear'])
    ].copy()

    _df = _df0_filtered.copy()
    #display(_df)

    # add options to _dfFiltersWithOptions
    
    _dfFiltersWithOptions = dfFilters.copy()

    # For each fCode, get the unique values from dfData, and join to dfFilters
    formatted_lists = []
    for fCode in dfFilters['fCode']:
        unique_values = [x for x in _df[fCode].unique() if pd.notna(x)]
        formatted_lists.append(unique_values)
    #display (formatted_lists)

    _dfFiltersWithOptions['fOptions'] = formatted_lists    
    #display(_dfFiltersWithOptions)

    # get list of fitler groups (any column that begins with f)
    fCols = [col for col in dfCombined_melt_withkeys_pivot_atts.columns if col.startswith('f')]
    _df[fCols] = _df[fCols].fillna('')
    _dfFilters = _df[fCols].drop_duplicates()

    # Drop rows with empty strings in ALL columns
    #_dfFilters = _dfFilters[~(_dfFilters == '').all(axis=1)]
    #display(_dfFilters)

    # Convert the values to binary form, so 1 where there is a value and 0 elsewhere
    binary_dfFilters = _dfFilters.applymap(lambda x: 0 if x=='' else 1)
    #display(binary_dfFilters)

    # Get unique rows of combinations
    unique_combinations = binary_dfFilters.drop_duplicates()

    # Convert the unique combinations to a list of tuples
    lstCombinations = list(unique_combinations.itertuples(index=False, name=None))
    #display(lstCombinations)

    # Define a function to convert to binary
    def is_empty_or_not(value):
        return 0 if value=='' else 1

    _dfFilterACodes = pd.DataFrame()

    jsonDataCombined = {}

    # loop through all combinations in list
    for combination in lstCombinations:

        # get list of column names with a 1 for given combination
        _dfFilterColsWithValue1 = [col for idx, col in enumerate(fCols) if combination[idx] == 1]
        #display(_dfFilterColsWithValue1)

        # create string of column names
        _strFilterGroup = '_'.join(_dfFilterColsWithValue1)
        #display(_strFilterGroup)
        
        # Initialize the condition as True for all rows
        condition = pd.Series([True] * len(_df), index=_df.index)

        # Apply the condition programmatically for each column in the list
        for col, comb_value in zip(fCols, combination):
            condition &= _df[col].apply(is_empty_or_not) == comb_value

        _filtered_df = _df[condition].copy()
        _filtered_df.drop(columns=['modVersion','scnGroup','scnYear'], inplace=True)
        #display(_filtered_df)

        # Remove columns where all values are NaN
        _filtered_df_noNA = _filtered_df.dropna(axis=1, how='all')
        #display(_filtered_df_noNA)

        _fColsToDrop = [col for col in _filtered_df_noNA.columns if col.startswith('f') and (_filtered_df_noNA[col] == '').all()]

        # Drop the identified columns - only have fCols with values
        _df2 = _filtered_df_noNA.drop(columns=_fColsToDrop)
        #display(_df2)

        # Get list of columns that begin with "a", create a dataframe the filter group for all possible combinations
        aCols = [col for col in _filtered_df_noNA.columns if col.startswith('a')]
        new_data = pd.DataFrame([{"filterGroup": _strFilterGroup, 'aCode': aCols}])
        new_data = new_data.explode('aCode').reset_index(drop=True)
        _dfFilterACodes = pd.concat([_dfFilterACodes, new_data], ignore_index=True)

        # get unique filter values
        _fColsRemain = [col for col in _df2.columns if col.startswith('f')]
        #display(_fColsRemain)
        if _fColsRemain:
            _dfFilterOptions = _df2[_fColsRemain].drop_duplicates()
        else:
            # add dummy row for no filter
            _dfFilterOptions = pd.DataFrame({'nofilter': ['']})

        #display(_dfFilterOptions)

        # Handle no filter data

        first_row = True

        for index, row in _dfFilterOptions.iterrows():

            # Function to convert a value to an integer if it's a whole number
            def convert_to_int_if_whole_number(value):
                try:
                    float_val = float(value)
                    if float_val.is_integer():
                        return str(int(float_val))
                    else:
                        return str(float_val)
                except ValueError:
                    return str(value)

            # Applying the function to each element and joining with '_'
            _filterRowIndex = '_'.join(row.apply(convert_to_int_if_whole_number).values)

            #print(_filterRowIndex)
            
            final_condition = ""

            if _fColsRemain != []:
                # Dynamically construct the filter condition
                shared_columns = set(_dfFilterOptions.columns) & set(_df2.columns)
                conditions = (_df2[col].isin([row[col]]) for col in shared_columns)
                final_condition = next(conditions)

                for condition in conditions:
                    final_condition &= condition

                filtered_df2 = _df2[final_condition].copy()
                filtered_df2.drop(columns=_fColsRemain, inplace=True)
            else: # no filter condition
                filtered_df2 =  _df2

            _df2noI = filtered_df2.reset_index()

            jsonDataForFilterOption = {}

            for index, row in _df2noI.iterrows():
                # Initialize an empty dictionary for the row
                row_dict = {}

                # Loop through each column that starts with 'a'
                for col in _df2noI.columns[_df2noI.columns.str.startswith('a')]:
                    # Add to row_dict if value is greater than 0
                    if row[col] > 0:
                        row_dict[col] = row[col]
                
                # If row_dict is not empty, add it to jsonDataCombined with TAZID as the key
                if row_dict:
                    jsonDataForFilterOption[row['SegID']] = row_dict 
            
            # Encapsulate jsonDataCombined under the _filterRowIndex
            final_json = {_filterRowIndex: jsonDataForFilterOption}

            ## Convert to a JSON formatted string
            #json_output = json.dumps(final_json)

            # Append the JSON structure from this iteration to the combined
            jsonDataCombined = {**jsonDataCombined, **final_json}

    _dfAttributesWFilter = pd.DataFrame.merge(dfAttributes, _dfFilterACodes, on='aCode')
    jsonAttributes = _dfAttributesWFilter.to_dict(orient='records')
    jsonFilters = _dfFiltersWithOptions.to_dict(orient='records')

    # Construct final JSON structure
    jsonScenario = {
        'scenarioDetails': jsonScenarioDetails,
        'attributes': jsonAttributes,
        'filters': jsonFilters,
        'data': jsonDataCombined#,
        #'aggregations': aggregations_list
    }

    # Specify the desired file name
    filename = '_site/data/scnData/' + _scenarioCode + '/' + outputJsonName + '.json'

    # Open the file in write mode
    with open(filename, 'w') as file:
        json.dump(jsonScenario, file)
        
display('Done!')
# Out:
# v900__Base__2019
# v900__Base__2023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28048\3779043579.py in <module>
#     155
#     156                 for condition in conditions:
# --> 157                     final_condition &= condition
#     158
#     159                 filtered_df2 = _df2[final_condition].copy()
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\generic.py in __iand__(self, other)
#   11402     def __iand__(self, other):
#   11403         # error: Unsupported left operand type for & ("Type[NDFrame]")
# > 11404         return self._inplace_method(other, type(self).__and__)  # type: ignore[operator]
#   11405
#   11406     def __ior__(self, other):
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\generic.py in _inplace_method(self, other, op)
#   11347         Wrap arithmetic method to operate inplace.
#   11348         """
# > 11349         result = op(self, other)
#   11350
#   11351         if (
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      68     @unpack_zerodim_and_defer("__and__")
#      69     def __and__(self, other):
# ---> 70         return self._logical_method(other, operator.and_)
#      71
#      72     @unpack_zerodim_and_defer("__rand__")
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    5632         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5633
# -> 5634         res_values = ops.logical_op(lvalues, rvalues, op)
#    5635         return self._construct_result(res_values, name=res_name)
#    5636
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     391         res_values = na_logical_op(lvalues, rvalues, op)
#     392         # error: Cannot call function of unknown type
# --> 393         res_values = filler(res_values)  # type: ignore[operator]
#     394
#     395     return res_values
#
# c:\Users\bhereth\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in fill_bool(x, left)
#     358
#     359         if left is None or is_bool_dtype(left.dtype):
# --> 360             x = x.astype(bool)
#     361         return x
#     362
#
# KeyboardInterrupt:
